# %% [markdown]
# # Package needed
# ## bs4
# ## tensorflow(or pytorch)

# %%
f = open("""./gakang_ton1_1.txt""", 'r', encoding='UTF8')
print(f.read())
# Out:
# Shuffle:
#   Seed: mt19937ar-sha512-n288-base64,...
#   Ref:
# Lobby 0:
#   Table: tenhou
#     red: True
#     kui: True
#     ton-nan: True
#     sanma: False
#     soku: False
# Players:
#   Index: Dan,     Rate, Sex, Name
#       0:  17,  2208.66,   M, 木漏れ日
#       1:  19,  2313.40,   M, お知らせ
#       2:  16,  2210.36,   M, komapia
#       3:  17,  2200.61,   M, 安達さくら
# Dealer: 0
# ========================================
# Initial Game State:
#   Round: Ton 1 Kyoku
#   Combo: 0
#   Reach: 0
#   Dice 1: 0
#   Dice 2: 4
#   Dora Indicator: 🀃 0
#   Initial Scores:
#        0:  25000
#        1:  25000
#        2:  25000
#        3:  25000
#   Dealer: 0
#   Initial Hands:
#       0: 🀈 1 🀊 1 🀊 3 🀚 1 🀜 2 🀝 1 🀐 0 🀑 0 🀔 0 🀕 1 🀕 2 🀂 3 🀃 2
#       1: 🀇 3 🀈 2 🀌 2 🀏 1 🀙 0 🀞 2 🀒 3 🀕 3 🀗 2 🀘 0 🀁 0 🀂 1 🀅 2
#       2: 🀇 0 🀇 2 🀎 1 🀏 3 🀚 2 🀜 3 🀞 0 🀓 0 🀓 3 🀘 3 🀁 2 🀂 2 🀅 0
#       3: 🀈 0 🀉 3 🀍 1 🀎 3 🀝 3 🀡 3 🀒 1 🀒 2 🀖 0 🀗 3 🀘 2 🀀 1 🀄 0
# Player 0: Draw    🀖 2
# Player 0: Discard 🀃 2
# Player 1: Draw    🀂 0
# Player 1: Discard 🀏 1
# Player 2: Draw    🀔 3
# Player 2: Discard 🀁 2
# Player 3: Draw    🀎 0
# Player 3: Discard 🀄 0
# Player 0: Draw    🀋 1
# Player 0: Discard 🀂 3
# Player 1: Draw    🀐 1
# Player 1: Discard 🀞 2
# Player 2: Draw    🀁 1
# Player 2: Discard 🀁 1
# Player 3: Draw    🀊 0
# Player 3: Discard 🀎 3
# Player 0: Draw    🀈 3
# Player 0: Discard 🀚 1
# Player 1: Draw    🀗 0
# Player 1: Discard 🀌 2
# Player 2: Draw    🀝 0
# Player 2: Discard 🀅 0
# Player 3: Draw    🀘 1
# Player 3: Discard 🀘 1
# Player 0: Draw    🀝 2
# Player 0: Discard 🀐 0
# Player 1: Draw    🀊 2
# Player 1: Discard 🀊 2
# Player 2: Draw    🀆 1
# Player 2: Discard 🀆 1
# Player 3: Draw    🀔 1
# Player 3: Discard 🀡 3
# Player 0: Draw    🀠 3
# Player 0: Discard 🀑 0
# Player 1: Draw    🀛 3
# Player 1: Discard 🀕 3
# Player 2: Draw    🀟 3
# Player 2: Discard 🀘 3
# Player 3: Draw    🀟 2
# Player 3: Discard 🀔 1
# Player 0: Draw    🀖 1
# Player 0: Discard 🀠 3
# Player 1: Draw    🀔 2
# Player 1: Discard 🀔 2
# Player 2: Draw    🀉 1
# Player 2: Discard 🀂 2
# Player 3: Draw    🀄 2
# Player 3: Discard 🀄 2
# Player 0: Draw    🀀 3
# Player 0: Discard 🀀 3
# Player 1: Draw    🀐 3
# Player 1: Discard 🀐 3
# Player 2: Draw    🀓 2
# Player 2: Discard 🀔 3
# Player 3: Draw    🀟 0
# Player 3: Discard 🀀 1
# Player 0: Draw    🀗 1
# Player 0: Discard 🀊 3
# Player 1: Draw    🀡 1
# Player 1: Discard 🀡 1
# Player 2: Draw    🀎 2
# Player 2: Discard 🀉 1
# Player 3: Draw    🀞 3
# Player 3: Reach
# Player 3: Discard 🀟 2
# Player 3 made deposite.
# New scores:
#        0:  25000
#        1:  25000
#        2:  25000
#        3:  24000
# Player 0: Draw    🀟 1
# Player 0: Discard 🀟 1
# Player 1: Draw    🀃 1
# Player 1: Discard 🀃 1
# Player 2: Draw    🀄 3
# Player 2: Discard 🀄 3
# Player 3: Draw    🀆 0
# Player 3: Discard 🀆 0
# Player 0: Draw    🀠 2
# Player 0: Discard 🀠 2
# Player 1: Draw    🀃 3
# Player 1: Discard 🀃 3
# Player 2: Draw    🀡 2
# Player 2: Discard 🀡 2
# Player 3: Draw    🀑 3
# Player 3: Discard 🀑 3
# Player 0: Draw    🀞 1
# Player 0: Reach
# Player 0: Discard 🀝 2
# Player 0 made deposite.
# New scores:
#        0:  24000
#        1:  25000
#        2:  25000
#        3:  24000
# Player 1: Draw    🀋 2
# Player 1: Discard 🀂 0
# Player 2: Draw    🀆 3
# Player 2: Discard 🀆 3
# Player 3: Draw    🀉 0
# Player 3: Discard 🀉 0
# Player 0 wins.
#   Ron from player 3
#   Hand: 🀈 1 🀈 3 🀉 0 🀊 1 🀋 1 🀜 2 🀝 1 🀞 1 🀔 0 🀕 1 🀕 2 🀖 1 🀖 2 🀗 1
#   Machi: 🀉 0
#   Dora Indicator: 🀃 0
#   Ura Dora: 🀕 0
#   Yaku:
#       Reach                ( 1):  1 [Han]
#       Ippatsu              ( 2):  1 [Han]
#       Pin-fu               ( 7):  1 [Han]
#       Tan-yao-chu          ( 8):  1 [Han]
#       Aka-dora             (54):  1 [Han]
#       Ura-dora             (53):  2 [Han]
#   Fu: 30
#   Score: 18000
#     - Haneman
#   Ten-bou:
#     Combo: 0
#     Reach: 2
#   Scores:
#      24000:  20000
#      25000:      0
#      25000:      0
#      24000: -18000
# ========================================
# Initial Game State:
#   Round: Ton 1 Kyoku
#   Combo: 1
#   Reach: 0
#   Dice 1: 4
#   Dice 2: 2
#   Dora Indicator: 🀀 0
#   Initial Scores:
#        0:  44000
#        1:  25000
#        2:  25000
#        3:   6000
#   Dealer: 0
#   Initial Hands:
#       0: 🀈 1 🀏 0 🀝 0 🀑 1 🀒 3 🀔 0 🀕 3 🀖 3 🀗 1 🀗 2 🀁 0 🀁 1 🀁 3
#       1: 🀍 1 🀍 3 🀎 0 🀚 3 🀛 0 🀛 1 🀜 1 🀞 0 🀡 0 🀒 1 🀂 1 🀅 1 🀄 3
#       2: 🀈 0 🀈 2 🀋 1 🀋 3 🀌 3 🀏 1 🀚 0 🀡 1 🀓 3 🀔 2 🀕 0 🀂 0 🀂 2
#       3: 🀇 0 🀉 2 🀋 2 🀍 0 🀙 1 🀙 2 🀚 2 🀟 2 🀠 3 🀑 2 🀓 1 🀕 1 🀄 0
# Player 0: Draw    🀜 0
# Player 0: Discard 🀏 0
# Player 1: Draw    🀘 0
# Player 1: Discard 🀂 1
# Player 2: Pon from player 1: 🀂 1🀂 0🀂 2
# Player 2: Discard 🀏 1
# Player 3: Draw    🀘 1
# Player 3: Discard 🀘 1
# Player 0: Draw    🀊 2
# Player 0: Discard 🀈 1
# Player 2: Pon from player 0: 🀈 2🀈 1🀈 0
# Player 2: Discard 🀡 1
# Player 3: Draw    🀂 3
# Player 3: Discard 🀂 3
# Player 0: Draw    🀖 0
# Player 0: Discard 🀊 2
# Player 1: Draw    🀟 0
# Player 1: Discard 🀅 1
# Player 2: Draw    🀈 3
# Player 2: KaKan: 🀈 0🀈 3🀈 1🀈 2
# Player 2: Draw    🀘 2
# New Dora Indicator: 🀖 2
# Player 2: Discard 🀘 2
# Player 3: Draw    🀊 0
# Player 3: Discard 🀄 0
# Player 0: Draw    🀀 2
# Player 0: Discard 🀀 2
# Player 1: Draw    🀗 3
# Player 1: Discard 🀄 3
# Player 2: Draw    🀅 2
# Player 2: Discard 🀅 2
# Player 3: Draw    🀆 3
# Player 3: Discard 🀆 3
# Player 0: Draw    🀃 3
# Player 0: Discard 🀃 3
# Player 1: Draw    🀉 3
# Player 1: Discard 🀉 3
# Player 2: Draw    🀠 0
# Player 2: Discard 🀠 0
# Player 3: Draw    🀃 1
# Player 3: Discard 🀃 1
# Player 0: Draw    🀠 1
# Player 0: Discard 🀠 1
# Player 1: Draw    🀄 2
# Player 1: Discard 🀄 2
# Player 2: Draw    🀇 3
# Player 2: Discard 🀇 3
# Player 3: Draw    🀜 3
# Player 3: Discard 🀇 0
# Player 0: Draw    🀅 3
# Player 0: Discard 🀅 3
# Player 1: Draw    🀔 1
# Player 1: Discard 🀡 0
# Player 2: Draw    🀞 2
# Player 2: Discard 🀚 0
# Player 3: Draw    🀙 3
# Player 3: Discard 🀍 0
# Player 0: Draw    🀅 0
# Player 0: Discard 🀅 0
# Player 1: Draw    🀓 0
# Player 1: Discard 🀛 1
# Player 2: Draw    🀇 2
# Player 2: Discard 🀇 2
# Player 3: Draw    🀑 3
# Player 3: Discard 🀜 3
# Player 0: Draw    🀐 3
# Player 0: Reach
# Player 0: Discard 🀖 3
# Player 0 made deposite.
# New scores:
#        0:  43000
#        1:  25000
#        2:  25000
#        3:   6000
# Player 1: Draw    🀐 1
# Player 1: Discard 🀍 1
# Player 2: Draw    🀐 2
# Player 2: Discard 🀌 3
# Player 3: Draw    🀛 2
# Player 3: Discard 🀊 0
# Player 0: Draw    🀘 3
# Player 0: Discard 🀘 3
# Player 1: Draw    🀡 2
# Player 1: Discard 🀘 0
# Player 2: Draw    🀎 2
# Player 2: Discard 🀎 2
# Player 3: Draw    🀌 2
# Player 3: Discard 🀌 2
# Player 0: Draw    🀝 2
# Player 0: Discard 🀝 2
# Player 1: Draw    🀇 1
# Player 1: Discard 🀎 0
# Player 2: Draw    🀎 3
# Player 2: Discard 🀎 3
# Player 3: Draw    🀌 1
# Player 3: Discard 🀌 1
# Player 0: Draw    🀟 1
# Player 0: Discard 🀟 1
# Player 1: Draw    🀟 3
# Player 1: Discard 🀟 3
# Player 2: Draw    🀗 0
# Player 2: Discard 🀋 3
# Player 3: Draw    🀍 2
# Player 3: Discard 🀋 2
# Player 0: Draw    🀀 1
# Player 0: Discard 🀀 1
# Player 1: Draw    🀊 3
# Player 1: Discard 🀇 1
# Player 2: Draw    🀆 0
# Player 2: Discard 🀋 1
# Player 3: Draw    🀚 1
# Player 3: Discard 🀟 2
# Player 0: Draw    🀜 2
# Player 0: Discard 🀜 2
# Player 1: Draw    🀋 0
# Player 1: Discard 🀍 3
# Player 2: Draw    🀆 2
# Player 2: Discard 🀆 0
# Player 3: Draw    🀠 2
# Player 3: Discard 🀍 2
# Player 0: Draw    🀝 3
# Player 0: Discard 🀝 3
# Player 1: Draw    🀙 0
# Player 1: Discard 🀜 1
# Player 2: Draw    🀌 0
# Player 2: Discard 🀆 2
# Player 3: Draw    🀏 2
# Player 3: Discard 🀙 2
# Player 0: Draw    🀕 2
# Player 0: Discard 🀕 2
# Player 1: Chi from player 0: 🀕 2🀓 0🀔 1
# Player 1: Discard 🀡 2
# Player 2: Draw    🀎 1
# Player 2: Discard 🀎 1
# Player 3: Draw    🀒 0
# Player 3: Discard 🀙 3
# Player 0: Draw    🀖 1
# Player 0: Discard 🀖 1
# Player 1: Draw    🀛 3
# Player 1: Discard 🀋 0
# Player 2: Draw    🀃 2
# Player 2: Discard 🀃 2
# Player 3: Draw    🀁 2
# Player 3: Discard 🀙 1
# Player 0: Draw    🀏 3
# Player 0: Discard 🀏 3
# Player 1: Draw    🀒 2
# Player 1: Discard 🀊 3
# Player 2: Draw    🀉 1
# Player 2: Discard 🀌 0
# Player 3: Draw    🀔 3
# Player 3: Discard 🀠 3
# Player 0: Draw    🀉 0
# Player 0: Discard 🀉 0
# Ryukyoku:
# Player 0: 🀜 0 🀝 0 🀐 3 🀑 1 🀒 3 🀔 0 🀕 3 🀖 0 🀗 1 🀗 2 🀁 0 🀁 1 🀁 3
#   Scores:
#      43000:   3000
#      25000:  -1000
#      25000:  -1000
#       6000:  -1000
#   Ten-bou:
#     Combo: 1
#     Reach: 1
# ========================================
# Initial Game State:
#   Round: Ton 1 Kyoku
#   Combo: 2
#   Reach: 1
#   Dice 1: 5
#   Dice 2: 2
#   Dora Indicator: 🀜 3
#   Initial Scores:
#        0:  46000
#        1:  24000
#        2:  24000
#        3:   5000
#   Dealer: 0
#   Initial Hands:
#       0: 🀈 0 🀊 0 🀊 2 🀋 2 🀍 1 🀛 2 🀛 3 🀞 2 🀠 1 🀐 2 🀔 0 🀗 1 🀘 3
#       1: 🀇 0 🀇 2 🀈 1 🀏 1 🀛 1 🀝 1 🀞 1 🀠 0 🀑 3 🀕 2 🀁 1 🀃 1 🀃 3
#       2: 🀈 3 🀌 0 🀌 1 🀍 3 🀚 1 🀟 1 🀑 1 🀓 3 🀔 2 🀖 0 🀀 0 🀃 2 🀆 1
#       3: 🀎 2 🀎 3 🀜 2 🀞 3 🀡 2 🀒 2 🀓 2 🀔 1 🀖 3 🀘 2 🀂 0 🀆 3 🀅 1
# Player 0: Draw    🀓 1
# Player 0: Discard 🀐 2
# Player 1: Draw    🀗 2
# Player 1: Discard 🀏 1
# Player 2: Draw    🀁 3
# Player 2: Discard 🀁 3
# Player 3: Draw    🀋 1
# Player 3: Discard 🀋 1
# Player 0: Draw    🀕 3
# Player 3 has left the game.
# Player 0: Discard 🀘 3
# Player 3 (安達さくら) has returned to the game.
# Player 1: Draw    🀄 2
# Player 1: Discard 🀁 1
# Player 2: Draw    🀂 1
# Player 2: Discard 🀃 2
# Player 3: Draw    🀁 0
# Player 3: Discard 🀁 0
# Player 0: Draw    🀙 2
# Player 0: Discard 🀗 1
# Player 1: Draw    🀀 1
# Player 1: Discard 🀑 3
# Player 2: Draw    🀉 1
# Player 2: Discard 🀀 0
# Player 3: Draw    🀂 3
# Player 3: Discard 🀡 2
# Player 0: Draw    🀆 2
# Player 0: Discard 🀆 2
# Player 1: Draw    🀈 2
# Player 1: Discard 🀠 0
# Player 2: Draw    🀒 0
# Player 2: Discard 🀆 1
# Player 3: Draw    🀋 0
# Player 3: Discard 🀆 3
# Player 0: Draw    🀟 2
# Player 0: Discard 🀙 2
# Player 1: Draw    🀐 1
# Player 1: Discard 🀐 1
# Player 2: Draw    🀖 1
# Player 2: Discard 🀂 1
# Player 3: Draw    🀘 0
# Player 3: Discard 🀅 1
# Player 0: Draw    🀍 0
# Player 0: Discard 🀈 0
# Player 1: Draw    🀔 3
# Player 1: Discard 🀗 2
# Player 2: Draw    🀇 3
# Player 2: Discard 🀚 1
# Player 3: Draw    🀗 0
# Player 3: Discard 🀘 2
# Player 0: Draw    🀉 2
# Player 0: Discard 🀊 2
# Player 1: Draw    🀐 3
# Player 1: Discard 🀐 3
# Player 2: Draw    🀄 1
# Player 2: Discard 🀄 1
# Player 3: Draw    🀄 3
# Player 3: Discard 🀄 3
# Player 0: Draw    🀊 1
# Player 0: Discard 🀊 1
# Player 1: Draw    🀆 0
# Player 1: Discard 🀛 1
# Player 0 wins.
#   Ron from player 1
#   Hand: 🀉 2 🀊 0 🀋 2 🀍 0 🀍 1 🀛 1 🀛 2 🀛 3 🀞 2 🀟 2 🀠 1 🀓 1 🀔 0 🀕 3
#   Machi: 🀛 1
#   Dora Indicator: 🀜 3
#   Yaku:
#       Tan-yao-chu          ( 8):  1 [Han]
#       Aka-dora             (54):  1 [Han]
#   Fu: 40
#   Score: 3900
#   Ten-bou:
#     Combo: 2
#     Reach: 1
#   Scores:
#      46000:   5500
#      24000:  -4500
#      24000:      0
#       5000:      0
# ========================================
# Initial Game State:
#   Round: Ton 1 Kyoku
#   Combo: 3
#   Reach: 0
#   Dice 1: 5
#   Dice 2: 4
#   Dora Indicator: 🀌 1
#   Initial Scores:
#        0:  51500
#        1:  19500
#        2:  24000
#        3:   5000
#   Dealer: 0
#   Initial Hands:
#       0: 🀉 2 🀎 2 🀛 0 🀟 1 🀒 3 🀓 2 🀕 1 🀖 1 🀖 3 🀘 3 🀂 2 🀃 3 🀅 1
#       1: 🀉 0 🀉 3 🀎 3 🀙 0 🀚 3 🀡 1 🀡 3 🀓 3 🀖 2 🀗 1 🀂 0 🀂 3 🀄 0
#       2: 🀇 1 🀊 2 🀌 3 🀚 2 🀞 1 🀠 1 🀐 0 🀑 1 🀁 0 🀃 2 🀆 2 🀅 2 🀄 3
#       3: 🀉 1 🀊 3 🀌 0 🀌 2 🀚 0 🀚 1 🀝 3 🀟 2 🀐 3 🀑 2 🀔 2 🀗 2 🀁 3
# Player 0: Draw    🀝 2
# Player 0: Discard 🀂 2
# Player 1: Draw    🀞 2
# Player 1: Discard 🀄 0
# Player 2: Draw    🀈 1
# Player 2: Discard 🀁 0
# Player 3: Draw    🀐 1
# Player 3: Discard 🀁 3
# Player 0: Draw    🀟 3
# Player 0: Discard 🀃 3
# Player 1: Draw    🀇 2
# Player 1: Discard 🀞 2
# Player 2: Draw    🀕 3
# Player 2: Discard 🀃 2
# Player 3: Draw    🀘 2
# Player 3: Discard 🀔 2
# Player 0: Draw    🀛 2
# Player 0: Discard 🀘 3
# Player 1: Draw    🀟 0
# Player 1: Discard 🀓 3
# Player 2: Draw    🀆 0
# Player 2: Discard 🀇 1
# Player 3: Draw    🀏 3
# Player 3: Discard 🀏 3
# Player 0: Draw    🀋 2
# Player 0: Discard 🀎 2
# Player 1: Draw    🀋 3
# Player 1: Discard 🀋 3
# Player 2: Draw    🀀 3
# Player 2: Discard 🀚 2
# Player 3: Draw    🀐 2
# Player 3: Discard 🀑 2
# Player 0: Draw    🀍 1
# Player 0: Discard 🀅 1
# Player 1: Draw    🀕 2
# Player 1: Discard 🀉 3
# Player 2: Draw    🀒 0
# Player 2: Discard 🀀 3
# Player 3: Draw    🀡 0
# Player 3: Discard 🀚 1
# Player 0: Draw    🀗 3
# Player 0: Discard 🀖 3
# Player 1: Draw    🀈 3
# Player 1: Discard 🀡 1
# Player 2: Draw    🀔 0
# Player 2: Discard 🀅 2
# Player 3: Draw    🀠 2
# Player 3: Discard 🀚 0
# Player 0: Draw    🀎 0
# Player 0: Discard 🀎 0
# Player 1: Draw    🀏 0
# Player 1: Discard 🀚 3
# Player 2: Draw    🀎 1
# Player 2: Discard 🀄 3
# Player 3: Draw    🀠 3
# Player 3: Discard 🀠 3
# Player 0: Draw    🀒 2
# Player 0: Discard 🀒 2
# Player 1: Draw    🀘 0
# Player 1: Discard 🀕 2
# Player 2: Draw    🀓 0
# Player 2: Discard 🀈 1
# Player 3: Draw    🀡 2
# Player 3: Discard 🀡 2
# Player 0: Draw    🀊 1
# Player 0: Discard 🀍 1
# Player 1: Chi from player 0: 🀍 1🀎 3🀏 0
# Player 1: Discard 🀙 0
# Player 2: Draw    🀒 1
# Player 2: Discard 🀒 1
# Player 3: Draw    🀞 0
# Player 3: Discard 🀗 2
# Player 0: Draw    🀀 1
# Player 0: Discard 🀀 1
# Player 1: Draw    🀔 3
# Player 1: Discard 🀔 3
# Player 2: Draw    🀋 1
# Player 2: Reach
# Player 2: Discard 🀎 1
# Player 2 made deposite.
# New scores:
#        0:  51500
#        1:  19500
#        2:  23000
#        3:   5000
# Player 3: Draw    🀙 1
# Player 3: Discard 🀙 1
# Player 0: Draw    🀍 2
# Player 0: Discard 🀒 3
# Player 1: Draw    🀇 0
# Player 1: Discard 🀇 0
# Player 2: Draw    🀅 3
# Player 2: Discard 🀅 3
# Player 3: Draw    🀈 2
# Player 3: Reach
# Player 3: Discard 🀘 2
# Player 3 made deposite.
# New scores:
#        0:  51500
#        1:  19500
#        2:  23000
#        3:   4000
# Player 0: Draw    🀘 1
# Player 0: Discard 🀘 1
# Player 1: Draw    🀙 3
# Player 1: Discard 🀙 3
# Player 2: Draw    🀁 2
# Player 2: Discard 🀁 2
# Player 3: Draw    🀜 0
# Player 3 wins.
#   Tsumo.
#   Hand: 🀈 2 🀉 1 🀊 3 🀌 0 🀌 2 🀜 0 🀝 3 🀞 0 🀟 2 🀠 2 🀡 0 🀐 1 🀐 2 🀐 3
#   Machi: 🀜 0
#   Dora Indicator: 🀌 1
#   Ura Dora: 🀄 2
#   Yaku:
#       Reach                ( 1):  1 [Han]
#       Ippatsu              ( 2):  1 [Han]
#       Tsumo                ( 0):  1 [Han]
#       Ura-dora             (53):  0 [Han]
#   Fu: 30
#   Score: 4000
#   Ten-bou:
#     Combo: 3
#     Reach: 2
#   Scores:
#      51500:  -2300
#      19500:  -1300
#      23000:  -1300
#       4000:   6900
# ========================================
# Initial Game State:
#   Round: Ton 2 Kyoku
#   Combo: 0
#   Reach: 0
#   Dice 1: 5
#   Dice 2: 2
#   Dora Indicator: 🀘 1
#   Initial Scores:
#        0:  49200
#        1:  18200
#        2:  21700
#        3:  10900
#   Dealer: 1
#   Initial Hands:
#       0: 🀇 1 🀉 0 🀋 1 🀙 2 🀚 2 🀜 1 🀞 1 🀠 1 🀑 3 🀔 2 🀕 3 🀘 3 🀅 3
#       1: 🀇 0 🀋 3 🀌 2 🀍 0 🀏 3 🀙 3 🀡 0 🀘 2 🀀 0 🀀 3 🀂 3 🀅 2 🀄 1
#       2: 🀈 3 🀍 1 🀎 1 🀜 2 🀝 0 🀝 1 🀟 0 🀑 2 🀖 1 🀃 2 🀆 0 🀅 1 🀄 3
#       3: 🀉 3 🀊 1 🀊 2 🀊 3 🀋 2 🀍 2 🀚 1 🀛 0 🀒 1 🀔 1 🀔 3 🀁 3 🀆 2
# Player 1: Draw    🀇 3
# Player 1: Discard 🀘 2
# Player 2: Draw    🀃 3
# Player 2: Discard 🀆 0
# Player 3: Draw    🀖 0
# Player 3: Discard 🀁 3
# Player 0: Draw    🀒 3
# Player 0: Discard 🀘 3
# Player 1: Draw    🀐 2
# Player 1: Discard 🀡 0
# Player 2: Draw    🀐 1
# Player 2: Discard 🀅 1
# Player 3: Draw    🀑 0
# Player 3: Discard 🀆 2
# Player 0: Draw    🀄 2
# Player 0: Discard 🀙 2
# Player 1: Draw    🀗 0
# Player 1: Discard 🀗 0
# Player 2: Draw    🀏 2
# Player 2: Discard 🀄 3
# Player 3: Draw    🀌 3
# Player 3: Discard 🀉 3
# Player 0: Draw    🀜 3
# Player 0: Discard 🀄 2
# Player 1: Draw    🀞 0
# Player 1: Discard 🀙 3
# Player 2: Draw    🀊 0
# Player 2: Discard 🀖 1
# Player 3: Draw    🀡 3
# Player 3: Discard 🀡 3
# Player 0: Draw    🀓 3
# Player 0: Discard 🀅 3
# Player 1: Draw    🀃 1
# Player 1: Discard 🀞 0
# Player 2: Draw    🀑 1
# Player 2: Discard 🀟 0
# Player 3: Draw    🀎 2
# Player 3: Discard 🀎 2
# Player 0: Draw    🀛 3
# Player 0: Discard 🀇 1
# Player 1: Pon from player 0: 🀇 1🀇 0🀇 3
# Player 1: Discard 🀐 2
# Player 2: Draw    🀞 3
# Player 2: Discard 🀝 1
# Player 3: Draw    🀁 2
# Player 3: Discard 🀁 2
# Player 0: Draw    🀞 2
# Player 0: Discard 🀠 1
# Player 1: Draw    🀔 0
# Player 1: Discard 🀔 0
# Player 2: Draw    🀏 1
# Player 2: Discard 🀏 1
# Player 3: Draw    🀃 0
# Player 3: Discard 🀃 0
# Player 0: Draw    🀒 0
# Player 0: Discard 🀜 3
# Player 1: Draw    🀆 1
# Player 1: Discard 🀆 1
# Player 2: Draw    🀈 1
# Player 2: Discard 🀑 1
# Player 3: Draw    🀐 3
# Player 3: Reach
# Player 3: Discard 🀖 0
# Player 3 made deposite.
# New scores:
#        0:  49200
#        1:  18200
#        2:  21700
#        3:   9900
# Player 0: Draw    🀄 0
# Player 0: Discard 🀄 0
# Player 1: Draw    🀙 0
# Player 1: Discard 🀄 1
# Player 2: Draw    🀅 0
# Player 2: Discard 🀅 0
# Player 3: Draw    🀚 0
# Player 3: Discard 🀚 0
# Player 0: Draw    🀐 0
# Player 0: Discard 🀚 2
# Player 1: Draw    🀕 0
# Player 1: Discard 🀅 2
# Player 2: Draw    🀖 3
# Player 2: Discard 🀖 3
# Player 3: Draw    🀌 0
# Player 3: Discard 🀌 0
# Player 0: Draw    🀕 2
# Player 0: Discard 🀉 0
# Player 1: Draw    🀌 1
# Player 1: Discard 🀃 1
# Player 2: Draw    🀏 0
# Player 2: Discard 🀏 0
# Player 3: Draw    🀓 1
# Player 3: Discard 🀓 1
# Player 0: Draw    🀠 2
# Player 0: Discard 🀓 3
# Player 1: Draw    🀎 3
# Player 1: Discard 🀌 2
# Player 2: Draw    🀡 1
# Player 2: Discard 🀡 1
# Player 3: Draw    🀟 1
# Player 3: Discard 🀟 1
# Player 0: Draw    🀉 1
# Player 0: Discard 🀉 1
# Player 1: Draw    🀚 3
# Player 1: Discard 🀎 3
# Player 2: Draw    🀜 0
# Player 2: Discard 🀃 2
# Player 3: Draw    🀓 0
# Player 3: Discard 🀓 0
# Player 0: Draw    🀙 1
# Player 0: Discard 🀋 1
# Player 1: Draw    🀂 0
# Player 1: Discard 🀏 3
# Player 2: Draw    🀀 2
# Player 2: Discard 🀃 3
# Player 3: Draw    🀟 3
# Player 3: Discard 🀟 3
# Player 0: Draw    🀛 2
# Player 0: Discard 🀠 2
# Player 1: Draw    🀗 2
# Player 1: Discard 🀚 3
# Player 2: Draw    🀕 1
# Player 2: Discard 🀏 2
# Player 3: Draw    🀎 0
# Player 3: Discard 🀎 0
# Player 0: Draw    🀂 1
# Player 0: Discard 🀂 1
# Player 1: Draw    🀉 2
# Player 1: Discard 🀉 2
# Player 2: Draw    🀇 2
# Player 2: Discard 🀎 1
# Player 3: Draw    🀆 3
# Player 3: Discard 🀆 3
# Player 0: Draw    🀀 1
# Player 0: Discard 🀐 0
# Player 1: Draw    🀟 2
# Player 1: Discard 🀟 2
# Player 2: Draw    🀠 3
# Player 2: Discard 🀐 1
# Player 3: Draw    🀡 2
# Player 3: Discard 🀡 2
# Player 0: Draw    🀗 1
# Player 0: Discard 🀙 1
# Player 3 wins.
#   Ron from player 0
#   Hand: 🀊 1 🀊 2 🀊 3 🀋 2 🀌 3 🀍 2 🀙 1 🀚 1 🀛 0 🀐 3 🀑 0 🀒 1 🀔 1 🀔 3
#   Machi: 🀙 1
#   Dora Indicator: 🀘 1
#   Ura Dora: 🀁 1
#   Yaku:
#       Reach                ( 1):  1 [Han]
#       Dora                 (52):  1 [Han]
#       Ura-dora             (53):  0 [Han]
#   Fu: 40
#   Score: 2600
#   Ten-bou:
#     Combo: 0
#     Reach: 1
#   Scores:
#      49200:  -2600
#      18200:      0
#      21700:      0
#       9900:   3600
# ========================================
# Initial Game State:
#   Round: Ton 3 Kyoku
#   Combo: 0
#   Reach: 0
#   Dice 1: 3
#   Dice 2: 1
#   Dora Indicator: 🀅 3
#   Initial Scores:
#        0:  46600
#        1:  18200
#        2:  21700
#        3:  13500
#   Dealer: 2
#   Initial Hands:
#       0: 🀋 2 🀌 0 🀎 3 🀏 0 🀜 1 🀞 1 🀠 2 🀡 2 🀐 0 🀕 1 🀗 1 🀁 3 🀃 1
#       1: 🀊 3 🀚 3 🀛 0 🀡 0 🀐 1 🀑 2 🀑 3 🀒 1 🀕 2 🀘 1 🀀 0 🀀 3 🀃 0
#       2: 🀇 3 🀈 2 🀉 1 🀍 0 🀛 1 🀜 0 🀞 2 🀟 0 🀠 0 🀓 1 🀓 2 🀀 1 🀆 0
#       3: 🀋 0 🀋 3 🀍 3 🀏 1 🀛 3 🀜 2 🀟 3 🀔 0 🀕 3 🀖 3 🀗 2 🀁 2 🀃 2
# Player 2: Draw    🀍 1
# Player 2: Discard 🀆 0
# Player 3: Draw    🀉 0
# Player 3: Discard 🀃 2
# Player 0: Draw    🀕 0
# Player 0: Discard 🀐 0
# Player 1: Draw    🀈 3
# Player 1: Discard 🀘 1
# Player 2: Draw    🀔 3
# Player 2: Discard 🀀 1
# Player 3: Draw    🀂 2
# Player 3: Discard 🀂 2
# Player 0: Draw    🀌 1
# Player 0: Discard 🀡 2
# Player 1: Draw    🀜 3
# Player 1: Discard 🀃 0
# Player 2: Draw    🀍 2
# Player 2: Reach
# Player 2: Discard 🀔 3
# Player 2 made deposite.
# New scores:
#        0:  46600
#        1:  18200
#        2:  20700
#        3:  13500
# Player 3: Draw    🀉 3
# Player 3: Discard 🀁 2
# Player 0: Draw    🀡 1
# Player 0: Discard 🀁 3
# Player 1: Draw    🀟 1
# Player 1: Discard 🀀 3
# Player 2: Draw    🀎 0
# Player 2: Discard 🀎 0
# Player 3: Draw    🀅 2
# Player 3: Discard 🀅 2
# Player 0: Draw    🀇 1
# Player 0: Discard 🀎 3
# Player 1: Draw    🀠 1
# Player 1: Discard 🀀 0
# Player 2: Draw    🀈 0
# Player 2: Discard 🀈 0
# Player 3: Draw    🀘 0
# Player 3: Discard 🀏 1
# Player 0: Draw    🀆 2
# Player 0: Discard 🀆 2
# Player 1: Draw    🀂 3
# Player 1: Discard 🀈 3
# Player 2: Draw    🀗 3
# Player 2: Discard 🀗 3
# Player 3: Draw    🀐 3
# Player 3: Discard 🀐 3
# Player 0: Draw    🀎 1
# Player 0: Discard 🀗 1
# Player 1: Draw    🀝 3
# Player 1: Discard 🀐 1
# Player 2: Draw    🀅 1
# Player 2: Discard 🀅 1
# Player 3: Draw    🀟 2
# Player 3: Discard 🀋 3
# Player 0: Draw    🀑 1
# Player 0: Discard 🀃 1
# Player 1: Draw    🀞 0
# Player 1: Discard 🀂 3
# Player 2: Draw    🀚 0
# Player 2 wins.
#   Tsumo.
#   Hand: 🀇 3 🀈 2 🀉 1 🀍 0 🀍 1 🀍 2 🀚 0 🀛 1 🀜 0 🀞 2 🀟 0 🀠 0 🀓 1 🀓 2
#   Machi: 🀚 0
#   Dora Indicator: 🀅 3
#   Ura Dora: 🀐 2
#   Yaku:
#       Reach                ( 1):  1 [Han]
#       Tsumo                ( 0):  1 [Han]
#       Ura-dora             (53):  0 [Han]
#   Fu: 30
#   Score: 3000
#   Ten-bou:
#     Combo: 0
#     Reach: 1
#   Scores:
#      46600:  -1000
#      18200:  -1000
#      20700:   4000
#      13500:  -1000
# ========================================
# Initial Game State:
#   Round: Ton 3 Kyoku
#   Combo: 1
#   Reach: 0
#   Dice 1: 3
#   Dice 2: 4
#   Dora Indicator: 🀑 3
#   Initial Scores:
#        0:  45600
#        1:  17200
#        2:  24700
#        3:  12500
#   Dealer: 2
#   Initial Hands:
#       0: 🀉 0 🀊 0 🀊 1 🀋 1 🀝 0 🀠 3 🀡 0 🀑 1 🀒 2 🀒 3 🀘 0 🀂 0 🀂 3
#       1: 🀈 2 🀋 2 🀍 1 🀚 2 🀝 2 🀞 2 🀔 3 🀗 3 🀘 2 🀀 3 🀁 3 🀆 1 🀅 0
#       2: 🀇 2 🀉 1 🀋 3 🀌 1 🀍 3 🀏 3 🀐 3 🀔 1 🀂 2 🀃 0 🀃 1 🀃 2 🀅 3
#       3: 🀇 3 🀌 2 🀙 1 🀚 3 🀜 0 🀜 1 🀞 0 🀐 2 🀓 1 🀕 0 🀕 3 🀖 1 🀗 1
# Player 2: Draw    🀓 0
# Player 2: Discard 🀐 3
# Player 3: Draw    🀡 1
# Player 3: Discard 🀡 1
# Player 0: Draw    🀊 2
# Player 0: Discard 🀘 0
# Player 1: Draw    🀁 1
# Player 1: Discard 🀀 3
# Player 2: Draw    🀌 0
# Player 2: Discard 🀂 2
# Player 0: Pon from player 2: 🀂 3🀂 2🀂 0
# Player 0: Discard 🀑 1
# Player 1: Draw    🀕 2
# Player 1: Discard 🀚 2
# Player 2: Draw    🀝 3
# Player 2: Discard 🀅 3
# Player 3: Draw    🀎 1
# Player 3: Discard 🀐 2
# Player 0: Draw    🀎 2
# Player 0: Discard 🀎 2
# Player 1: Draw    🀎 3
# Player 1: Discard 🀅 0
# Player 2: Draw    🀆 2
# Player 2: Discard 🀆 2
# Player 3: Draw    🀏 1
# Player 3: Discard 🀇 3
# Player 0: Draw    🀝 1
# Player 0: Discard 🀠 3
# Player 1: Draw    🀜 2
# Player 1: Discard 🀆 1
# Player 2: Draw    🀑 2
# Player 2: Discard 🀑 2
# Player 3: Draw    🀙 2
# Player 3: Discard 🀏 1
# Player 0: Draw    🀗 0
# Player 0: Discard 🀗 0
# Player 1: Draw    🀗 2
# Player 1: Discard 🀈 2
# Player 2: Draw    🀈 0
# Player 2: Discard 🀝 3
# Player 0: Pon from player 2: 🀝 1🀝 3🀝 0
# Player 0: Discard 🀡 0
# Player 1: Draw    🀡 2
# Player 1: Discard 🀡 2
# Player 2: Draw    🀈 1
# Player 2: Discard 🀈 1
# Player 3: Draw    🀞 3
# Player 3: Discard 🀎 1
# Player 0: Draw    🀀 2
# Player 0: Discard 🀀 2
# Player 1: Draw    🀙 3
# Player 1: Discard 🀘 2
# Player 2: Draw    🀈 3
# Player 2: Discard 🀈 3
# Player 3: Draw    🀌 3
# Player 3: Discard 🀗 1
# Player 0: Draw    🀔 2
# Player 0: Discard 🀔 2
# Player 1: Draw    🀠 2
# Player 1: Discard 🀠 2
# Player 2: Draw    🀄 3
# Player 2: Discard 🀄 3
# Player 3: Draw    🀟 1
# Player 3: Discard 🀟 1
# Player 0: Draw    🀛 1
# Player 0: Discard 🀛 1
# Player 1: Draw    🀟 2
# Player 1: Discard 🀗 2
# Player 2: Draw    🀒 0
# Player 2: Reach
# Player 2: Discard 🀌 1
# Player 2 made deposite.
# New scores:
#        0:  45600
#        1:  17200
#        2:  23700
#        3:  12500
# Player 3: Draw    🀉 3
# Player 3: Discard 🀌 2
# Player 0: Chi from player 3: 🀌 2🀊 0🀋 1
# Player 0: Discard 🀊 2
# Player 1: Draw    🀜 3
# Player 1: Discard 🀝 2
# Player 2: Draw    🀛 0
# Player 2: Discard 🀛 0
# Player 3: Draw    🀞 1
# Player 3: Discard 🀌 3
# Player 0: Draw    🀄 0
# Player 0: Discard 🀄 0
# Player 1: Draw    🀖 3
# Player 1: Discard 🀁 1
# Player 2: Draw    🀄 1
# Player 2: Discard 🀄 1
# Player 3: Draw    🀁 0
# Player 3: Discard 🀁 0
# Player 0: Draw    🀏 2
# Player 0: Discard 🀏 2
# Player 2 wins.
#   Ron from player 0
#   Hand: 🀇 2 🀈 0 🀉 1 🀋 3 🀌 0 🀍 3 🀏 2 🀏 3 🀒 0 🀓 0 🀔 1 🀃 0 🀃 1 🀃 2
#   Machi: 🀏 2
#   Dora Indicator: 🀑 3
#   Ura Dora: 🀘 1
#   Yaku:
#       Reach                ( 1):  1 [Han]
#       Dora                 (52):  1 [Han]
#       Ura-dora             (53):  0 [Han]
#   Fu: 40
#   Score: 3900
#   Ten-bou:
#     Combo: 1
#     Reach: 1
#   Scores:
#      45600:  -4200
#      17200:      0
#      23700:   5200
#      12500:      0
# ========================================
# Initial Game State:
#   Round: Ton 3 Kyoku
#   Combo: 2
#   Reach: 0
#   Dice 1: 3
#   Dice 2: 3
#   Dora Indicator: 🀖 3
#   Initial Scores:
#        0:  41400
#        1:  17200
#        2:  28900
#        3:  12500
#   Dealer: 2
#   Initial Hands:
#       0: 🀊 1 🀊 3 🀙 3 🀛 1 🀜 0 🀟 0 🀟 3 🀠 0 🀑 0 🀑 2 🀓 0 🀕 1 🀀 2
#       1: 🀉 3 🀋 0 🀚 1 🀚 2 🀚 3 🀞 1 🀞 3 🀡 2 🀕 3 🀗 0 🀗 2 🀁 3 🀄 1
#       2: 🀌 0 🀌 2 🀏 3 🀝 0 🀠 2 🀐 1 🀒 0 🀓 1 🀔 1 🀀 0 🀆 1 🀆 2 🀄 0
#       3: 🀈 1 🀈 3 🀌 1 🀙 2 🀚 0 🀞 0 🀡 3 🀐 2 🀔 0 🀔 3 🀘 0 🀃 1 🀄 2
# Player 2: Draw    🀟 2
# Player 2: Discard 🀏 3
# Player 3: Draw    🀉 2
# Player 3: Discard 🀃 1
# Player 0: Draw    🀂 0
# Player 0: Discard 🀙 3
# Player 1: Draw    🀔 2
# Player 1: Discard 🀁 3
# Player 2: Draw    🀖 0
# Player 2: Discard 🀄 0
# Player 3: Draw    🀜 3
# Player 3: Discard 🀡 3
# Player 0: Draw    🀉 1
# Player 0: Discard 🀀 2
# Player 1: Draw    🀒 2
# Player 1: Discard 🀡 2
# Player 2: Draw    🀁 1
# Player 2: Discard 🀁 1
# Player 3: Draw    🀛 3
# Player 3: Discard 🀄 2
# Player 0: Draw    🀛 0
# Player 0: Discard 🀂 0
# Player 1: Draw    🀑 3
# Player 1: Discard 🀄 1
# Player 2: Draw    🀀 3
# Player 2: Discard 🀐 1
# Player 3: Draw    🀂 2
# Player 3: Discard 🀂 2
# Player 0: Draw    🀎 3
# Player 0: Discard 🀎 3
# Player 1: Draw    🀗 3
# Player 1: Discard 🀑 3
# Player 2: Draw    🀓 3
# Player 2: Discard 🀓 3
# Player 3: Draw    🀖 1
# Player 3: Discard 🀐 2
# Player 0: Draw    🀂 3
# Player 0: Discard 🀂 3
# Player 1: Draw    🀉 0
# Player 1: Discard 🀒 2
# Player 2: Draw    🀇 0
# Player 2: Discard 🀇 0
# Player 3: Draw    🀖 2
# Player 3: Discard 🀌 1
# Player 2: Pon from player 3: 🀌 0🀌 2🀌 1
# Player 2: Discard 🀖 0
# Player 3: Draw    🀝 1
# Player 3: Discard 🀈 1
# Player 0: Draw    🀅 2
# Player 0: Discard 🀓 0
# Player 1: Chi from player 0: 🀓 0🀔 2🀕 3
# Player 1: Discard 🀋 0
# Player 2: Draw    🀡 1
# Player 2: Discard 🀝 0
# Player 3: Draw    🀏 0
# Player 3: Discard 🀏 0
# Player 0: Draw    🀇 2
# Player 0: Discard 🀇 2
# Player 1: Draw    🀗 1
# Player 1: AnKan: 🀗 0🀗 1
# New Dora Indicator: 🀋 2
# Player 1: Draw    🀝 3
# Player 1: Discard 🀞 3
# Player 2: Draw    🀐 3
# Player 2: Discard 🀐 3
# Player 3: Draw    🀘 2
# Player 3: Discard 🀖 2
# Player 0: Draw    🀍 3
# Player 0: Discard 🀑 2
# Player 1: Draw    🀅 3
# Player 1: Discard 🀅 3
# Player 2: Draw    🀎 0
# Player 2: Discard 🀎 0
# Player 3: Draw    🀙 1
# Player 3: Discard 🀙 1
# Player 0: Draw    🀠 3
# Player 0: Discard 🀅 2
# Player 1: Draw    🀋 1
# Player 1: Discard 🀋 1
# Player 2: Draw    🀊 0
# Player 2: Discard 🀊 0
# Player 3: Draw    🀈 0
# Player 3: Discard 🀈 0
# Player 0: Draw    🀍 2
# Player 0: Discard 🀑 0
# Player 1: Draw    🀒 1
# Player 1: Discard 🀒 1
# Player 2: Draw    🀟 1
# Player 2: Discard 🀟 1
# Player 1 wins.
#   Ron from player 2
#   Hand: 🀉 0 🀉 3 🀚 1 🀚 2 🀚 3 🀝 3 🀞 1 🀟 1
#   Machi: 🀟 1
#   Dora Indicator: 🀖 3 🀋 2
#   Yaku:
#       Tan-yao-chu          ( 8):  1 [Han]
#       Dora                 (52):  4 [Han]
#   Fu: 40
#   Score: 8000
#     - Mangan
#   Ten-bou:
#     Combo: 2
#     Reach: 0
#   Scores:
#      41400:      0
#      17200:   8600
#      28900:  -8600
#      12500:      0
# ========================================
# Initial Game State:
#   Round: Ton 4 Kyoku
#   Combo: 0
#   Reach: 0
#   Dice 1: 5
#   Dice 2: 2
#   Dora Indicator: 🀁 0
#   Initial Scores:
#        0:  41400
#        1:  25800
#        2:  20300
#        3:  12500
#   Dealer: 3
#   Initial Hands:
#       0: 🀈 1 🀉 2 🀎 1 🀚 2 🀠 1 🀠 3 🀕 1 🀕 2 🀗 3 🀀 2 🀆 0 🀅 0 🀄 0
#       1: 🀊 3 🀋 1 🀎 3 🀚 0 🀜 0 🀝 0 🀝 3 🀞 3 🀟 0 🀟 2 🀠 2 🀒 2 🀂 1
#       2: 🀍 3 🀏 1 🀚 1 🀛 0 🀜 3 🀞 2 🀟 3 🀒 3 🀓 2 🀘 2 🀂 3 🀆 2 🀄 2
#       3: 🀇 3 🀈 0 🀉 1 🀊 0 🀎 0 🀏 0 🀛 2 🀛 3 🀝 2 🀘 0 🀘 3 🀆 1 🀆 3
# Player 3: Draw    🀋 0
# Player 3: Discard 🀘 0
# Player 0: Draw    🀙 3
# Player 0: Discard 🀀 2
# Player 1: Draw    🀊 2
# Player 1: Discard 🀂 1
# Player 2: Draw    🀅 1
# Player 2: Discard 🀄 2
# Player 3: Draw    🀀 0
# Player 3: Discard 🀘 3
# Player 0: Draw    🀝 1
# Player 0: Discard 🀆 0
# Player 3: Pon from player 0: 🀆 1🀆 3🀆 0
# Player 3: Discard 🀝 2
# Player 0: Draw    🀃 3
# Player 0: Discard 🀅 0
# Player 1: Draw    🀞 1
# Player 1: Discard 🀎 3
# Player 2: Draw    🀐 2
# Player 2: Discard 🀅 1
# Player 3: Draw    🀡 3
# Player 3: Discard 🀡 3
# Player 0: Draw    🀈 3
# Player 0: Discard 🀃 3
# Player 1: Draw    🀞 0
# Player 1: Discard 🀚 0
# Player 2: Draw    🀇 2
# Player 2: Discard 🀇 2
# Player 3: Draw    🀂 0
# Player 3: Discard 🀛 3
# Player 0: Draw    🀖 3
# Player 0: Discard 🀄 0
# Player 1: Draw    🀚 3
# Player 1: Discard 🀚 3
# Player 2: Draw    🀍 0
# Player 2: Discard 🀐 2
# Player 3: Draw    🀁 3
# Player 3: Discard 🀛 2
# Player 0: Draw    🀉 0
# Player 0: Discard 🀎 1
# Player 1: Draw    🀒 1
# Player 1: Reach
# Player 1: Discard 🀊 2
# Player 1 made deposite.
# New scores:
#        0:  41400
#        1:  24800
#        2:  20300
#        3:  12500
# Player 2: Draw    🀘 1
# Player 2: Discard 🀂 3
# Player 3: Draw    🀋 2
# Player 3: Discard 🀂 0
# Player 0: Draw    🀒 0
# Player 0: Discard 🀚 2
# Player 1: Draw    🀀 1
# Player 1: Discard 🀀 1
# Player 2: Draw    🀋 3
# Player 2: Discard 🀆 2
# Player 3: Draw    🀗 1
# Player 3: Discard 🀀 0
# Player 0: Draw    🀄 1
# Player 0: Discard 🀄 1
# Player 1: Draw    🀏 3
# Player 1: Discard 🀏 3
# Player 2: Draw    🀇 0
# Player 2: Discard 🀏 1
# Player 3: Draw    🀓 1
# Player 3: Discard 🀁 3
# Player 0: Draw    🀁 2
# Player 0: Discard 🀁 2
# Player 1: Draw    🀏 2
# Player 1: Discard 🀏 2
# Player 2: Draw    🀗 2
# Player 2: Discard 🀚 1
# Player 3: Draw    🀇 1
# Player 3: Discard 🀏 0
# Player 0: Draw    🀃 2
# Player 0: Discard 🀃 2
# Player 1: Draw    🀍 2
# Player 1: Discard 🀍 2
# Player 2: Draw    🀃 0
# Player 2: Discard 🀍 3
# Player 3: Draw    🀄 3
# Player 3: Discard 🀄 3
# Player 0: Draw    🀠 0
# Player 0: Discard 🀙 3
# Player 1: Draw    🀅 3
# Player 1: Discard 🀅 3
# Player 2: Draw    🀑 1
# Player 2: Discard 🀍 0
# Player 3: Draw    🀖 1
# Player 3: Discard 🀎 0
# Player 0: Draw    🀈 2
# Player 0: Discard 🀈 2
# Player 1: Draw    🀌 1
# Player 1 wins.
#   Tsumo.
#   Hand: 🀊 3 🀋 1 🀌 1 🀜 0 🀝 0 🀝 3 🀞 0 🀞 1 🀞 3 🀟 0 🀟 2 🀠 2 🀒 1 🀒 2
#   Machi: 🀌 1
#   Dora Indicator: 🀁 0
#   Ura Dora: 🀜 1
#   Yaku:
#       Reach                ( 1):  1 [Han]
#       Tsumo                ( 0):  1 [Han]
#       Pin-fu               ( 7):  1 [Han]
#       Tan-yao-chu          ( 8):  1 [Han]
#       Aka-dora             (54):  1 [Han]
#       Ura-dora             (53):  2 [Han]
#   Fu: 20
#   Score: 12000
#     - Haneman
#   Ten-bou:
#     Combo: 0
#     Reach: 1
#   Scores:
#      41400:  -3000
#      24800:  13000
#      20300:  -3000
#      12500:  -6000
# ========================================
# Initial Game State:
#   Round: Nan 1 Kyoku
#   Combo: 0
#   Reach: 0
#   Dice 1: 0
#   Dice 2: 5
#   Dora Indicator: 🀃 1
#   Initial Scores:
#        0:  38400
#        1:  37800
#        2:  17300
#        3:   6500
#   Dealer: 0
#   Initial Hands:
#       0: 🀈 2 🀉 2 🀉 3 🀊 1 🀋 2 🀎 3 🀏 0 🀙 3 🀝 2 🀠 0 🀠 3 🀘 0 🀘 2
#       1: 🀋 0 🀌 3 🀍 3 🀙 1 🀟 1 🀐 0 🀒 0 🀒 1 🀓 0 🀗 3 🀁 1 🀆 0 🀆 1
#       2: 🀇 1 🀌 0 🀌 1 🀚 1 🀛 3 🀜 1 🀞 0 🀞 1 🀞 3 🀟 0 🀡 2 🀐 2 🀂 3
#       3: 🀇 0 🀉 1 🀎 2 🀙 2 🀚 2 🀜 3 🀝 0 🀟 2 🀠 2 🀡 1 🀀 1 🀁 2 🀂 1
# Player 0: Draw    🀑 3
# Player 0: Discard 🀙 3
# Player 1: Draw    🀎 1
# Player 1: Discard 🀙 1
# Player 2: Draw    🀔 0
# Player 2: Discard 🀂 3
# Player 3: Draw    🀀 3
# Player 3: Discard 🀂 1
# Player 0: Draw    🀂 2
# Player 0: Discard 🀂 2
# Player 1: Draw    🀖 3
# Player 1: Discard 🀐 0
# Player 2: Draw    🀋 1
# Player 2: Discard 🀇 1
# Player 3: Draw    🀓 1
# Player 3: Discard 🀎 2
# Player 0: Draw    🀈 0
# Player 0: Discard 🀑 3
# Player 1: Draw    🀒 2
# Player 1: Discard 🀁 1
# Player 2: Draw    🀍 0
# Player 2: Discard 🀐 2
# Player 3: Draw    🀐 1
# Player 3: Discard 🀐 1
# Player 0: Draw    🀅 3
# Player 0: Discard 🀅 3
# Player 1: Draw    🀌 2
# Player 1: Discard 🀟 1
# Player 2: Draw    🀍 1
# Player 2: Discard 🀡 2
# Player 3: Draw    🀄 1
# Player 3: Discard 🀁 2
# Player 0: Draw    🀓 3
# Player 0: Discard 🀓 3
# Player 1: Draw    🀁 0
# Player 1: Discard 🀁 0
# Player 2: Draw    🀗 0
# Player 2: Discard 🀗 0
# Player 3: Draw    🀊 0
# Player 3: Discard 🀇 0
# Player 0: Draw    🀊 3
# Player 0: Discard 🀋 2
# Player 1: Draw    🀙 0
# Player 1: Discard 🀙 0
# Player 2: Draw    🀔 2
# Player 2: Reach
# Player 2: Discard 🀟 0
# Player 2 made deposite.
# New scores:
#        0:  38400
#        1:  37800
#        2:  16300
#        3:   6500
# Player 3: Draw    🀂 0
# Player 3: Discard 🀂 0
# Player 0: Draw    🀗 1
# Player 0: Discard 🀗 1
# Player 1: Draw    🀃 3
# Player 1: Discard 🀗 3
# Player 2: Draw    🀑 2
# Player 2: Discard 🀑 2
# Player 3: Draw    🀅 1
# Player 3: Discard 🀅 1
# Player 0: Draw    🀖 1
# Player 0: Discard 🀘 2
# Player 1: Draw    🀜 0
# Player 1: Discard 🀆 0
# Player 2: Draw    🀠 1
# Player 2: Discard 🀠 1
# Player 3: Draw    🀀 2
# Player 3: Discard 🀄 1
# Player 0: Draw    🀛 2
# Player 0: Discard 🀘 0
# Player 1: Draw    🀃 2
# Player 1: Discard 🀆 1
# Player 2: Draw    🀚 0
# Player 2: Discard 🀚 0
# Player 3: Draw    🀛 0
# Player 3: Discard 🀓 1
# Player 0: Draw    🀖 0
# Player 0: Discard 🀠 3
# Player 1: Draw    🀑 1
# Player 1: Discard 🀖 3
# Player 2: Draw    🀐 3
# Player 2: Discard 🀐 3
# Player 3: Draw    🀁 3
# Player 3: Discard 🀁 3
# Player 0: Draw    🀝 1
# Player 0: Discard 🀠 0
# Player 1: Draw    🀏 2
# Player 1: Discard 🀃 3
# Player 2: Draw    🀕 1
# Player 2: Discard 🀕 1
# Player 3: Draw    🀘 1
# Player 3: Discard 🀘 1
# Player 0: Draw    🀈 1
# Player 0: Discard 🀖 1
# Player 1: Draw    🀍 2
# Player 1: Discard 🀃 2
# Player 2: Draw    🀘 3
# Player 2: Discard 🀘 3
# Player 3: Draw    🀚 3
# Player 3: Reach
# Player 3: Discard 🀙 2
# Player 3 made deposite.
# New scores:
#        0:  38400
#        1:  37800
#        2:  16300
#        3:   5500
# Player 0: Draw    🀖 2
# Player 0: Discard 🀖 2
# Player 1: Draw    🀜 2
# Player 1: Discard 🀓 0
# Player 2: Draw    🀆 3
# Player 2: Discard 🀆 3
# Player 3: Draw    🀅 0
# Player 3: Discard 🀅 0
# Player 0: Draw    🀛 1
# Player 0: Discard 🀖 0
# Player 1: Draw    🀟 3
# Player 1: Discard 🀑 1
# Player 2: Draw    🀒 3
# Player 2: Discard 🀒 3
# Player 3: Draw    🀗 2
# Player 3: Discard 🀗 2
# Player 0: Draw    🀋 3
# Player 0: Discard 🀏 0
# Player 1: Draw    🀡 0
# Player 1: Discard 🀏 2
# Player 2: Draw    🀏 3
# Player 2: Discard 🀏 3
# Player 3: Draw    🀆 2
# Player 3: Discard 🀆 2
# Player 0: Draw    🀑 0
# Player 0: Discard 🀑 0
# Player 1: Draw    🀇 3
# Player 1: Discard 🀇 3
# Player 2: Draw    🀃 0
# Player 2: Discard 🀃 0
# Player 3: Draw    🀕 2
# Player 3: Discard 🀕 2
# Player 0: Draw    🀎 0
# Player 0: Discard 🀈 2
# Player 3 wins.
#   Ron from player 0
#   Hand: 🀈 2 🀉 1 🀊 0 🀚 2 🀚 3 🀛 0 🀜 3 🀝 0 🀟 2 🀠 2 🀡 1 🀀 1 🀀 2 🀀 3
#   Machi: 🀈 2
#   Dora Indicator: 🀃 1
#   Ura Dora: 🀡 3
#   Yaku:
#       Reach                ( 1):  1 [Han]
#       Dora                 (52):  3 [Han]
#       Aka-dora             (54):  1 [Han]
#       Ura-dora             (53):  0 [Han]
#   Fu: 40
#   Score: 8000
#     - Mangan
#   Ten-bou:
#     Combo: 0
#     Reach: 2
#   Scores:
#      38400:  -8000
#      37800:      0
#      16300:      0
#       5500:  10000
# ========================================
# Initial Game State:
#   Round: Nan 2 Kyoku
#   Combo: 0
#   Reach: 0
#   Dice 1: 3
#   Dice 2: 0
#   Dora Indicator: 🀚 0
#   Initial Scores:
#        0:  30400
#        1:  37800
#        2:  16300
#        3:  15500
#   Dealer: 1
#   Initial Hands:
#       0: 🀇 0 🀉 0 🀋 0 🀋 2 🀌 2 🀛 3 🀜 0 🀜 3 🀠 1 🀘 1 🀘 3 🀁 1 🀃 2
#       1: 🀉 1 🀉 3 🀍 3 🀏 0 🀚 3 🀝 2 🀐 0 🀐 3 🀕 3 🀖 3 🀁 2 🀆 0 🀆 2
#       2: 🀈 3 🀊 3 🀏 2 🀏 3 🀞 1 🀟 3 🀒 1 🀓 0 🀓 2 🀔 3 🀃 0 🀄 0 🀄 3
#       3: 🀌 3 🀛 0 🀝 3 🀞 0 🀠 3 🀡 1 🀐 2 🀕 2 🀖 2 🀀 1 🀁 0 🀁 3 🀅 1
# Player 1: Draw    🀇 2
# Player 1: Discard 🀚 3
# Player 2: Draw    🀇 3
# Player 2: Discard 🀇 3
# Player 3: Draw    🀅 3
# Player 3: Discard 🀀 1
# Player 0: Draw    🀖 0
# Player 0: Discard 🀁 1
# Player 3: Pon from player 0: 🀁 0🀁 3🀁 1
# Player 3: Discard 🀐 2
# Player 0: Draw    🀅 0
# Player 0: Discard 🀅 0
# Player 3: Pon from player 0: 🀅 1🀅 3🀅 0
# Player 3: Discard 🀡 1
# Player 0: Draw    🀍 0
# Player 0: Discard 🀃 2
# Player 1: Draw    🀞 2
# Player 1: Discard 🀁 2
# Player 2: Draw    🀜 1
# Player 2: Discard 🀃 0
# Player 3: Draw    🀕 0
# Player 3: Discard 🀠 3
# Player 0: Draw    🀝 0
# Player 0: Discard 🀠 1
# Player 1: Draw    🀖 1
# Player 1: Discard 🀍 3
# Player 2: Draw    🀑 1
# Player 2: Discard 🀜 1
# Player 3: Chi from player 2: 🀜 1🀛 0🀝 3
# Player 3: Discard 🀞 0
# Player 0: Draw    🀊 1
# Player 0: Discard 🀇 0
# Player 1: Draw    🀈 1
# Player 1: Discard 🀐 0
# Player 2: Draw    🀎 2
# Player 2: Discard 🀈 3
# Player 3: Draw    🀈 2
# Player 3: Discard 🀈 2
# Player 0: Draw    🀙 0
# Player 0: Discard 🀙 0
# Player 1: Draw    🀂 0
# Player 1: Discard 🀐 3
# Player 2: Draw    🀂 1
# Player 2: Discard 🀂 1
# Player 3: Draw    🀒 3
# Player 3: Discard 🀒 3
# Player 0: Draw    🀘 2
# Player 0: Reach
# Player 0: Discard 🀜 3
# Player 0 made deposite.
# New scores:
#        0:  29400
#        1:  37800
#        2:  16300
#        3:  15500
# Player 1: Draw    🀓 3
# Player 1: Discard 🀇 2
# Player 2: Draw    🀑 3
# Player 2: Discard 🀄 0
# Player 3: Draw    🀏 1
# Player 3: Discard 🀏 1
# Player 0: Draw    🀋 3
# Player 0: Discard 🀋 3
# Player 1: Draw    🀠 0
# Player 1: Discard 🀏 0
# Player 2: Draw    🀀 2
# Player 2: Discard 🀄 3
# Player 3: Draw    🀙 3
# Player 3: Discard 🀙 3
# Player 0: Draw    🀔 1
# Player 0: Discard 🀔 1
# Player 1: Draw    🀎 1
# Player 1: Discard 🀈 1
# Player 2: Draw    🀀 0
# Player 2: Discard 🀔 3
# Player 3: Draw    🀗 3
# Player 3: Discard 🀌 3
# Player 0: Draw    🀙 2
# Player 0: Discard 🀙 2
# Player 1: Draw    🀛 1
# Player 1: Discard 🀠 0
# Player 2: Draw    🀂 3
# Player 2: Discard 🀏 3
# Player 3: Draw    🀉 2
# Player 3: Discard 🀉 2
# Player 0: Draw    🀈 0
# Player 0: Discard 🀈 0
# Player 1: Draw    🀒 2
# Player 1: Discard 🀉 1
# Player 2: Draw    🀇 1
# Player 2: Discard 🀏 2
# Player 3: Draw    🀑 0
# Player 3: Discard 🀑 0
# Player 0: Draw    🀌 1
# Player 0: Discard 🀌 1
# Player 1: Draw    🀀 3
# Player 1: Discard 🀉 3
# Player 2: Draw    🀗 2
# Player 2: Discard 🀑 1
# Player 3: Draw    🀝 1
# Player 3: Discard 🀝 1
# Player 0: Draw    🀄 1
# Player 0: Discard 🀄 1
# Player 1: Draw    🀎 3
# Player 1: Discard 🀝 2
# Player 2: Draw    🀔 0
# Player 2: Discard 🀑 3
# Player 3: Draw    🀅 2
# Player 3: Discard 🀅 2
# Player 0: Draw    🀊 0
# Player 0: Discard 🀊 0
# Player 1: Draw    🀑 2
# Player 1: Discard 🀑 2
# Player 2: Draw    🀆 1
# Player 2: Discard 🀊 3
# Player 3: Draw    🀡 2
# Player 3: Discard 🀡 2
# Player 0: Draw    🀄 2
# Player 0: Discard 🀄 2
# Player 1: Draw    🀕 1
# Player 1: Discard 🀕 1
# Player 3 wins.
#   Ron from player 1
#   Hand: 🀕 0 🀕 1 🀕 2 🀖 2 🀗 3
#   Machi: 🀕 1
#   Dora Indicator: 🀚 0
#   Yaku:
#       Nan                  (15):  1 [Han]
#       Hatsu                (19):  1 [Han]
#       Dora                 (52):  1 [Han]
#   Fu: 30
#   Score: 3900
#   Ten-bou:
#     Combo: 0
#     Reach: 1
#   Scores:
#      29400:      0
#      37800:  -3900
#      16300:      0
#      15500:   4900
# ========================================
# Initial Game State:
#   Round: Nan 3 Kyoku
#   Combo: 0
#   Reach: 0
#   Dice 1: 2
#   Dice 2: 2
#   Dora Indicator: 🀀 2
#   Initial Scores:
#        0:  29400
#        1:  33900
#        2:  16300
#        3:  20400
#   Dealer: 2
#   Initial Hands:
#       0: 🀉 0 🀌 1 🀙 2 🀚 1 🀛 0 🀛 2 🀜 3 🀝 3 🀔 0 🀘 2 🀀 1 🀀 3 🀆 1
#       1: 🀈 3 🀌 2 🀌 3 🀍 0 🀍 3 🀎 2 🀙 0 🀐 0 🀑 3 🀔 1 🀘 1 🀃 0 🀃 1
#       2: 🀇 0 🀇 2 🀉 3 🀍 1 🀏 2 🀞 3 🀠 2 🀐 1 🀑 1 🀓 3 🀁 2 🀂 1 🀅 1
#       3: 🀈 2 🀋 0 🀛 1 🀛 3 🀝 0 🀝 2 🀟 0 🀟 3 🀓 1 🀂 0 🀂 2 🀃 3 🀅 0
# Player 2: Draw    🀗 3
# Player 2: Discard 🀂 1
# Player 3: Draw    🀂 3
# Player 3: Discard 🀈 2
# Player 0: Draw    🀕 1
# Player 0: Discard 🀘 2
# Player 1: Draw    🀉 1
# Player 1: Discard 🀘 1
# Player 2: Draw    🀊 0
# Player 2: Discard 🀐 1
# Player 3: Draw    🀕 3
# Player 3: Discard 🀓 1
# Player 0: Draw    🀎 0
# Player 0: Discard 🀆 1
# Player 1: Draw    🀁 1
# Player 1: Discard 🀙 0
# Player 2: Draw    🀝 1
# Player 2: Discard 🀅 1
# Player 3: Draw    🀑 2
# Player 3: Discard 🀑 2
# Player 0: Draw    🀗 0
# Player 0: Discard 🀗 0
# Player 1: Draw    🀟 2
# Player 1: Discard 🀔 1
# Player 2: Draw    🀖 1
# Player 2: Discard 🀠 2
# Player 3: Draw    🀋 1
# Player 3: Discard 🀕 3
# Player 0: Draw    🀅 3
# Player 0: Discard 🀅 3
# Player 1: Draw    🀔 2
# Player 1: Discard 🀔 2
# Player 2: Draw    🀒 0
# Player 2: Discard 🀍 1
# Player 3: Draw    🀓 2
# Player 3: Discard 🀓 2
# Player 0: Draw    🀄 1
# Player 0: Discard 🀄 1
# Player 1: Draw    🀄 3
# Player 1: Discard 🀟 2
# Player 3: Pon from player 1: 🀟 3🀟 2🀟 0
# Player 3: Discard 🀃 3
# Player 0: Draw    🀡 0
# Player 0: Discard 🀡 0
# Player 1: Draw    🀗 2
# Player 1: Discard 🀗 2
# Player 2: Draw    🀏 3
# Player 2: Discard 🀁 2
# Player 3: Draw    🀇 3
# Player 3: Discard 🀇 3
# Player 0: Draw    🀀 0
# Player 0: Discard 🀉 0
# Player 1: Draw    🀡 3
# Player 1: Discard 🀁 1
# Player 2: Draw    🀊 2
# Player 2: Discard 🀇 2
# Player 3: Draw    🀏 1
# Player 3: Discard 🀏 1
# Player 0: Draw    🀊 1
# Player 0: Discard 🀊 1
# Player 1: Draw    🀚 2
# Player 1: Discard 🀡 3
# Player 2: Draw    🀡 2
# Player 2: Discard 🀇 0
# Player 3: Draw    🀆 3
# Player 3: Discard 🀆 3
# Player 0: Draw    🀇 1
# Player 0: Discard 🀇 1
# Player 1: Draw    🀗 1
# Player 1: Discard 🀗 1
# Player 2: Draw    🀐 2
# Player 2: Discard 🀡 2
# Player 3: Draw    🀘 3
# Player 3: Discard 🀘 3
# Player 0: Draw    🀋 2
# Player 0: Discard 🀎 0
# Player 1: Draw    🀐 3
# Player 1: Discard 🀄 3
# Player 2: Draw    🀠 1
# Player 2: Discard 🀠 1
# Player 3: Draw    🀓 0
# Player 3: Discard 🀓 0
# Player 0: Draw    🀌 0
# Player 0: Discard 🀋 2
# Player 3: Pon from player 0: 🀋 0🀋 1🀋 2
# Player 3: Discard 🀅 0
# Player 0: Draw    🀜 1
# Player 0: Discard 🀙 2
# Player 1: Draw    🀟 1
# Player 1: Discard 🀟 1
# Player 2: Chi from player 1: 🀟 1🀝 1🀞 3
# Player 2: Discard 🀐 2
# Player 3: Draw    🀚 0
# Player 3: Discard 🀚 0
# Player 0: Draw    🀎 3
# Player 0: Discard 🀎 3
# Player 1: Chi from player 0: 🀎 3🀌 2🀍 0
# Player 1: Discard 🀚 2
# Player 2: Draw    🀆 0
# Player 2: Discard 🀆 0
# Player 3: Draw    🀅 2
# Player 3: Discard 🀅 2
# Player 0: Draw    🀙 3
# Player 0: Reach
# Player 0: Discard 🀙 3
# Player 0 made deposite.
# New scores:
#        0:  28400
#        1:  33900
#        2:  16300
#        3:  20400
# Player 1: Draw    🀖 2
# Player 1: Discard 🀎 2
# Player 2: Draw    🀠 0
# Player 2: Discard 🀠 0
# Player 3: Draw    🀃 2
# Player 3: Discard 🀃 2
# Player 0: Draw    🀁 0
# Player 0: Discard 🀁 0
# Player 1: Draw    🀘 0
# Player 1: Discard 🀃 1
# Player 2: Draw    🀞 0
# Player 2: Discard 🀊 0
# Player 3: Draw    🀕 2
# Player 3: Discard 🀂 3
# Player 0: Draw    🀄 0
# Player 0: Discard 🀄 0
# Player 1: Draw    🀊 3
# Player 1: Discard 🀃 0
# Player 2: Draw    🀡 1
# Player 2: Discard 🀡 1
# Player 3: Draw    🀍 2
# Player 3: Discard 🀂 2
# Player 0: Draw    🀖 3
# Player 0 wins.
#   Tsumo.
#   Hand: 🀌 0 🀌 1 🀚 1 🀛 0 🀛 2 🀜 1 🀜 3 🀝 3 🀔 0 🀕 1 🀖 3 🀀 0 🀀 1 🀀 3
#   Machi: 🀖 3
#   Dora Indicator: 🀀 2
#   Ura Dora: 🀒 1
#   Yaku:
#       Reach                ( 1):  1 [Han]
#       Tsumo                ( 0):  1 [Han]
#       Aka-dora             (54):  1 [Han]
#       Ura-dora             (53):  0 [Han]
#   Fu: 30
#   Score: 4000
#   Ten-bou:
#     Combo: 0
#     Reach: 1
#   Scores:
#      28400:   5000
#      33900:  -1000
#      16300:  -2000
#      20400:  -1000
# ========================================
# Initial Game State:
#   Round: Nan 4 Kyoku
#   Combo: 0
#   Reach: 0
#   Dice 1: 3
#   Dice 2: 0
#   Dora Indicator: 🀓 0
#   Initial Scores:
#        0:  33400
#        1:  32900
#        2:  14300
#        3:  19400
#   Dealer: 3
#   Initial Hands:
#       0: 🀋 3 🀌 2 🀏 0 🀏 2 🀛 1 🀞 0 🀟 1 🀐 1 🀒 0 🀒 3 🀓 1 🀁 1 🀅 3
#       1: 🀉 2 🀊 1 🀌 0 🀞 3 🀠 3 🀡 3 🀑 3 🀔 0 🀗 0 🀂 1 🀆 0 🀅 2 🀄 0
#       2: 🀇 0 🀊 0 🀊 2 🀙 3 🀞 1 🀠 2 🀐 0 🀑 0 🀔 1 🀀 3 🀃 3 🀄 2 🀄 3
#       3: 🀈 0 🀈 2 🀉 3 🀍 3 🀏 3 🀚 2 🀜 3 🀑 1 🀓 2 🀕 0 🀕 1 🀀 1 🀃 0
# Player 3: Draw    🀔 2
# Player 3: Discard 🀃 0
# Player 0: Draw    🀍 1
# Player 0: Discard 🀅 3
# Player 1: Draw    🀙 2
# Player 1: Discard 🀙 2
# Player 2: Draw    🀘 3
# Player 2: Discard 🀀 3
# Player 3: Draw    🀌 3
# Player 3: Discard 🀀 1
# Player 0: Draw    🀎 0
# Player 0: Discard 🀁 1
# Player 1: Draw    🀟 3
# Player 1: Discard 🀅 2
# Player 2: Draw    🀎 3
# Player 2: Discard 🀇 0
# Player 3: Draw    🀎 1
# Player 3: Discard 🀑 1
# Player 0: Draw    🀖 0
# Player 0: Discard 🀐 1
# Player 1: Draw    🀡 2
# Player 1: Discard 🀆 0
# Player 2: Draw    🀠 0
# Player 2: Discard 🀙 3
# Player 3: Draw    🀐 3
# Player 3: Discard 🀐 3
# Player 0: Draw    🀙 0
# Player 0: Discard 🀖 0
# Player 1: Draw    🀉 0
# Player 1: Discard 🀄 0
# Player 2: Draw    🀒 2
# Player 2: Discard 🀎 3
# Player 3: Draw    🀗 2
# Player 3: Discard 🀏 3
# Player 0: Draw    🀁 3
# Player 0: Discard 🀁 3
# Player 1: Draw    🀛 2
# Player 1: Discard 🀂 1
# Player 2: Draw    🀇 3
# Player 2: Discard 🀇 3
# Player 3: Draw    🀕 2
# Player 3: Discard 🀗 2
# Player 0: Draw    🀜 0
# Player 0: Discard 🀙 0
# Player 1: Draw    🀚 1
# Player 1: Discard 🀑 3
# Player 2: Draw    🀂 3
# Player 2: Discard 🀂 3
# Player 3: Draw    🀠 1
# Player 3: Discard 🀠 1
# Player 2: Pon from player 3: 🀠 0🀠 2🀠 1
# Player 2: Discard 🀘 3
# Player 3: Draw    🀟 0
# Player 3: Discard 🀟 0
# Player 0: Draw    🀍 0
# Player 0: Discard 🀏 2
# Player 1: Draw    🀒 1
# Player 1: Discard 🀗 0
# Player 2: Draw    🀞 2
# Player 2: Discard 🀃 3
# Player 3: Draw    🀘 2
# Player 3: Discard 🀘 2
# Player 0: Draw    🀃 1
# Player 0: Discard 🀃 1
# Player 1: Draw    🀛 0
# Player 1: Discard 🀡 2
# Player 2: Draw    🀎 2
# Player 2: Discard 🀎 2
# Player 3: Draw    🀆 1
# Player 3: Discard 🀆 1
# Player 0: Draw    🀆 2
# Player 0: Discard 🀆 2
# Player 1: Draw    🀀 0
# Player 1: Discard 🀡 3
# Player 2: Draw    🀝 1
# Player 2: Discard 🀊 2
# Player 3: Chi from player 2: 🀊 2🀈 0🀉 3
# Player 3: Discard 🀈 2
# Player 0: Draw    🀡 1
# Player 0: Discard 🀡 1
# Player 1: Draw    🀊 3
# Player 1: Discard 🀌 0
# Player 2: Draw    🀏 1
# Player 2: Discard 🀊 0
# Player 1: Pon from player 2: 🀊 1🀊 3🀊 0
# Player 1: Discard 🀀 0
# Player 2: Draw    🀝 3
# Player 2: Discard 🀏 1
# Player 3: Draw    🀋 1
# Player 3: Discard 🀎 1
# Player 0: Draw    🀅 0
# Player 0: Discard 🀅 0
# Player 1: Draw    🀉 1
# Player 1: Discard 🀚 1
# Player 2: Draw    🀐 2
# Player 2: Discard 🀐 2
# Player 3: Draw    🀈 1
# Player 3: Discard 🀈 1
# Player 0: Draw    🀚 0
# Player 0: Discard 🀏 0
# Player 1: Draw    🀜 1
# Player 1: Discard 🀜 1
# Player 2: Draw    🀌 1
# Player 2: Discard 🀌 1
# Player 3: Draw    🀟 2
# Player 3: Discard 🀟 2
# Player 0: Draw    🀝 0
# Player 0: Discard 🀎 0
# Player 1: Draw    🀁 2
# Player 1: Discard 🀁 2
# Player 2: Draw    🀗 1
# Player 2: Discard 🀗 1
# Player 3: Draw    🀂 0
# Player 3: Discard 🀂 0
# Player 0: Draw    🀋 2
# Player 0: Discard 🀌 2
# Player 1: Draw    🀛 3
# Player 1: Discard 🀉 0
# Player 2: Draw    🀅 1
# Player 2: Discard 🀅 1
# Player 3: Draw    🀙 1
# Player 3: Discard 🀙 1
# Player 0: Draw    🀇 2
# Player 0: Discard 🀇 2
# Player 1: Draw    🀁 0
# Player 1: Discard 🀁 0
# Player 2: Draw    🀄 1
# Player 2: Discard 🀔 1
# Player 3: Draw    🀗 3
# Player 3: Discard 🀗 3
# Player 0: Draw    🀃 2
# Player 0: Discard 🀃 2
# Player 1: Draw    🀚 3
# Player 1: Discard 🀚 3
# Player 2: Draw    🀓 3
# Player 2: Discard 🀐 0
# Player 3: Draw    🀋 0
# Player 3: Discard 🀌 3
# Player 0: Draw    🀖 2
# Player 0: Discard 🀚 0
# Player 1: Draw    🀜 2
# Player 1: Discard 🀜 2
# Player 2: Draw    🀝 2
# Player 2: Discard 🀄 3
# Player 3: Draw    🀈 3
# Player 3: Discard 🀈 3
# Ryukyoku:
# Player 1: 🀉 1 🀉 2 🀛 0 🀛 2 🀛 3 🀞 3 🀟 3 🀠 3 🀒 1 🀔 0
# Player 2: 🀝 1 🀝 2 🀝 3 🀞 1 🀞 2 🀑 0 🀒 2 🀓 3 🀄 1 🀄 2
#   Scores:
#      33400:  -1500
#      32900:   1500
#      14300:   1500
#      19400:  -1500
#   Ten-bou:
#     Combo: 0
#     Reach: 0
#   Result:
#      31900:   12.0
#      34400:   44.0
#      15800:  -34.0
#      17900:  -22.0

# %% [markdown]
# # Input Data Preprocessing

# %%
from bs4 import BeautifulSoup
import re

f = open("""./gakang_ton1_1.txt""", 'r', encoding='UTF8')
fTxt = f.read()

#1KyokuSpliter
KyokuSplit = fTxt.split('='*40)
kyoku = 8
MaxKyoku = len(KyokuSplit)-1 #패보 앞에 metadata 뺀 실제 국 수
KyokuSSplit = KyokuSplit[kyoku].split('\n')
nPlayer = 1

#N번 플레이어 배패 
KyokuAllHand = KyokuSplit[kyoku].split('Initial Hands:')
InitialHands = KyokuAllHand[1].split('\n')
nPlayerInitialHands = re.findall(r"[^A-Za-z0-9: ]+", InitialHands[nPlayer+1])

Haibo = [line for line in KyokuSSplit if 'Player ' in line]

#N번 플레이어 버림패
def PlayerKawa(nPlayer):
    Kawa = [line[-3] for line in KyokuSSplit if 'Player '+ str(nPlayer) +': Discard ' in line]
    return Kawa

#N번 플레이어 쯔모패
def PlayerDraw(nPlayer):
    Draw = []
    for idx, line in enumerate(KyokuSSplit):
        if 'Player '+ str(nPlayer) +': Draw ' in line:
            Draw.append(line[-3])
        elif ('Player '+str(nPlayer)+': Pon' in line or
        'Player '+str(nPlayer)+': Chi' in line):
            #line == KyokuSSplit[idx]
            Draw.append(KyokuSSplit[idx-1][-3])
        elif 'Player '+str(nPlayer)+': AnKan' in line or 'Player '+str(nPlayer)+': KaKan' in line:
            del Draw[-1]
        elif 'Player '+str(nPlayer)+': MinKan' in line:
            pass
            
    return Draw

#n번 플레이어 n순 받은 패
#mengen == NumNaki = 0
def PlayerNaki(nPlayer):
    NumNaki = 0 # 멘젠
    Naki = {}
    for idx, line in enumerate(Haibo):
        if ('Player '+str(nPlayer)+': Pon' in line or
        'Player '+str(nPlayer)+': Chi' in line or
        'Player '+str(nPlayer)+': AnKan' in line or
        'Player '+str(nPlayer)+': MinKan' in line):
            NumNaki +=1
            KeyName = line.split(':')
            Naki[KeyName[1]] = re.findall(r"[^A-Za-z0-9: ]+", line)
        elif 'Player '+str(nPlayer)+': KaKan' in line:
            KanHai = re.findall(r"[^A-Za-z0-9: ]+", line)
            for Pon in Naki.values():
                if Pon[0] == KanHai[0]:
                    Pon.append(KanHai[0])
    
    if NumNaki > 4:
        print("Naki err")
    
    return Naki

#n번 플레이어 n순 손패
nPlayerHands = nPlayerInitialHands

TotalTurn = len(PlayerKawa(nPlayer))
for nTurn in range(TotalTurn):
    nPlayerHands.append(PlayerDraw(nPlayer)[nTurn])
    nPlayerHands.sort()
    nPlayerHands.remove(PlayerKawa(nPlayer)[nTurn])
    
print(nPlayerHands)
print(PlayerNaki(nPlayer))
#마작 버림패 최대 수 24매
# Out:
# ['🀉', '🀉', '🀓', '🀔', '🀕', '🀗', '🀗', '🀗', '🀚', '🀚', '🀚', '🀝', '🀞']
# {' Chi from player 0': ['🀓', '🀔', '🀕'], ' AnKan': ['🀗', '🀗']}

# %%
import tensorflow as tf

# Training Parameters
learning_rate = 0.001
training_steps = 12
batch_size = 1 # 데이터양
display_step = 1

#타패 선택지 모든 패 경우 34장 중 하나로

# Network Parameters
num_input = (24+4*4)*4+14 # 4명의 최대 {버림패(24)+받은패(4*4)} + 손패 14
timesteps = 24 # 최대 버림패
num_hidden = 128 # hidden layer num of features
num_classes = 14 # 손패 14장

# tf Graph input
X = tf.placeholder("float", [None, timesteps, num_input])
Y = tf.placeholder("float", [None, num_classes])

# Define weights
weights = {
    'out': tf.Variable(tf.random_normal([num_hidden, num_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([num_classes]))
}
def RNN(x, weights, biases):
    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, timesteps, n_input)
    # Required shape: 'timesteps' tensors list of shape (batch_size, n_input)

    # Unstack to get a list of 'timesteps' tensors of shape (batch_size, n_input)
    x = tf.unstack(x, timesteps, 1)

    # Define a lstm cell with tensorflow
    lstm_cell = tf.nn.rnn_cell.BasicLSTMCell(num_hidden, forget_bias=1.0)

    # Get lstm cell output
    outputs, states = tf.nn.static_rnn(lstm_cell, x, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

#with tf.device('/device:GPU:0'):
logits = RNN(X, weights, biases)
prediction = tf.nn.softmax(logits)

# Define loss and optimizer
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(
    logits=logits, labels=Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)

# Evaluate model (with test logits, for dropout to be disabled)
correct_pred = tf.equal(tf.argmax(prediction, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# Start training
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.log_device_placement=True
with tf.Session(config=config) as sess:
    sess.run(init)
    for step in range(1, training_steps+1):
#        batch_x, batch_y = mnist.train.next_batch(batch_size)
#        batch_x = batch_x.reshape((batch_size, timesteps, num_input))
        # Run optimization op (backprop)
        sess.run(train_op, feed_dict={X: batch_x, Y: batch_y})
        if step % display_step == 0 or step == 1:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([loss_op, accuracy], feed_dict={X: batch_x,
                                                                 Y: batch_y})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.3f}".format(acc))

    print("Optimization Finished!")

'''    # Calculate accuracy for 128 mnist test images
    test_len = 128
    test_data = mnist.test.images[:test_len].reshape((-1, timesteps, num_input))
    test_label = mnist.test.labels[:test_len]
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={X: test_data, Y: test_label}))'''
