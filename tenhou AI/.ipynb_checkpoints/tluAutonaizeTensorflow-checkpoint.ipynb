# %%
f = open("""./result.txt""", 'r', encoding='UTF8')
print(f.read())
# Out:
# Shuffle:
#   Seed: mt19937ar-sha512-n288-base64,...
#   Ref:
# Lobby 0:
#   Table: tenhou
#     red: True
#     kui: True
#     ton-nan: True
#     sanma: False
#     soku: False
# Players:
#   Index: Dan,     Rate, Sex, Name
#       0:  16,  2144.71,   M, サブアラド
#       1:  17,  2260.13,   M, ＼(＾o＾)／★
#       2:  16,  2150.40,   M, 素振り猫
#       3:  16,  2121.89,   M, ジャスミン
# Dealer: 0
# ...
# Initial Game State:
#   Round: Ton 1 Kyoku
#   Combo: 0
#   Reach: 0
#   Dice 1: 1
#   Dice 2: 1
#   Dora Indicator: 🀀 1
#   Initial Scores:
#        0:  25000
#        1:  25000
#        2:  25000
#        3:  25000
#   Dealer: 0
#   Initial Hands:
#       0: 🀒 1 🀓 2 🀓 3 🀖 2 🀚 0 🀟 3 🀡 2 🀈 2 🀉 1 🀌 3 🀂 0 🀃 2 🀄 2
#       1: 🀒 0 🀔 2 🀘 1 🀘 2 🀚 3 🀝 2 🀠 0 🀋 1 🀋 3 🀌 2 🀎 2 🀂 2 🀄 1
#       2: 🀐 0 🀐 2 🀑 1 🀖 0 🀙 2 🀚 2 🀛 0 🀇 1 🀊 3 🀋 0 🀀 3 🀃 1 🀄 3
#       3: 🀕 0 🀕 2 🀗 1 🀜 3 🀝 1 🀞 0 🀞 2 🀡 1 🀊 2 🀍 3 🀎 3 🀁 0 🀄 0
# Player 0: Draw    🀎 0
# Player 0: Discard 🀃 2
# Player 1: Draw    🀚 1
# Player 1: Discard 🀂 2
# ...

# %%
from bs4 import BeautifulSoup

f = open("""./result.txt""", 'r', encoding='UTF8')
#print(f.read())
fTxt = f.read()

#1KyokuSpliter
KyokuSplit = fTxt.split('========================================')
#print(KyokuSplit[1])

#nPlayerData
#KyoukuSSplit = KyokuSplit[1].split('\n')
nPlayer = 3
KyoukuSSplit = KyokuSplit[1].split('\n')
Player0TurnNKawa = [line for line in KyoukuSSplit if " 0:" in line]
#print(matching)
Player0TurnN = KyokuSplit[1].split('Player '+ str(nPlayer) +': Discard ')

#0번 플레이어 버림패 = test data
Player0Kawa = [line[18:-2] for line in KyoukuSSplit if 'Player '+ str(nPlayer) +': Discard ' in line]
#print(Player0Kawa)
def PlayerKawa(nPlayer):
    Kawa = [line[18:-2] for line in KyoukuSSplit if 'Player '+ str(nPlayer) +': Discard ' in line]
    return Kawa
    
#print(PlayerKawa(nPlayer))
# Out:
# ['🀡', '🀄', '🀇', '🀡', '🀃', '🀆', '🀂', '🀁', '🀊', '🀗', '🀖']
